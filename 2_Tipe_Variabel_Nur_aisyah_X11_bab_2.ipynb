# %% [markdown]
# <a href="https://colab.research.google.com/github/nuraisyahh/KKA-X-Semester-1/blob/main/2_Tipe_Variabel_Nur_aisyah_X11_bab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Nur aisyah
#
# Kelas:X.11
#
# No.absen:26

# %% [markdown]
# #Konsep dasar Variabel

# %%
print("nuraisyah.2025@gmail.com")
print("nuraisyah.3025@gmail.com")
print("nuraisyah.3025@gmail.com")
# Out:
# nuraisyah.2025@gmail.com
# nuraisyah.3025@gmail.com
# nuraisyah.3025@gmail.com

# %%
email_user_1 = "nuraisyah.3025@gmail.con"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# nuraisyah.3025@gmail.con
# nuraisyah.3025@gmail.con
# nuraisyah.3025@gmail.con

# %% [markdown]
# #Peraturan penamaan variabel

# %%
#hanya diperbolehkan menggunakan huruf, angka, dan under score
email user 2 = "bobbyaliando@mail.com"

print (email user 2)
# Out:
#   File "/tmp/ipython-input-4090814422.py", line 2
#     email user 2 = "bobbyaliando@mail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 = "bobbyaliando@mail.com"

print(emailuser2)
# Out:
# bobbyaliando@mail.com

# %%
#Tidal boleh didahului oleh angka
3_email_user = "willytaulany@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-143863650.py", line 2
#     3_email_user = "willytaulany@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "willytaulany@gmail.com"

print (email_user_3)
# Out:
# willytaulany@gmail.com

# %%
#Tidak boleh menggunakan kata kunci python
for = "HimamHimawan@gmail.com"
# Out:
#   File "/tmp/ipython-input-3021037871.py", line 2
#     for = "HimamHimawan@gmail.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "HimamHimawan@gmail.com"

print(For)
# Out:
# HimamHimawan@gmail.com

# %%
print = "Juliawati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1948412904.py in <cell line: 0>()
#       1 print = "Juliawati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Juliawati@gmail.com"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3159628512.py in <cell line: 0>()
#       1 Print = "Juliawati@gmail.com"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %%
#tidak error tapi dilanjutkan harus deskriptif
_="Devandraarnoldi@gmail.com"

print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3959190466.py in <cell line: 0>()
#       2 _="Devandraarnoldi@gmail.com"
#       3
# ----> 4 print(_)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Assigment

# %%
#Single assignment
nama_mahasiswa_1 = "Alexandrio"

print(nama_mahasiswa_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3870658017.py in <cell line: 0>()
#       2 nama_mahasiswa_1 = "Alexandrio"
#       3
# ----> 4 print(nama_mahasiswa_1)
#
# TypeError: 'str' object is not callable

# %%
#Multiple Assignment

#nama_barang_1 = "rinso"
#nama_barang_2 = "molto

nama_barang_1, nama_barang_2 = " rinso", "molto"

# %%
#Assignment yang sama
nilai_devandra = nilai_willy = nilai_dzakki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzakki)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-86504466.py in <cell line: 0>()
#       2 nilai_devandra = nilai_willy = nilai_dzakki = 100
#       3
# ----> 4 print(nilai_devandra)
#       5 print(nilai_willy)
#       6 print(nilai_dzakki)
#
# TypeError: 'str' object is not callable

# %%
#Menimpa/Mengubah Nilai Variabel

nilai_himam = 95

# %%
print(nilai_himam)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2701357047.py in <cell line: 0>()
# ----> 1 print(nilai_himam)
#
# TypeError: 'str' object is not callable

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2701357047.py in <cell line: 0>()
# ----> 1 print(nilai_himam)
#
# TypeError: 'str' object is not callable

# %%
#Tanpa Variabel
print(20+3)
# Out:
# 23

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss = 20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#soal no. 1 (Tanpa variabel)
print(24 * 3)
# Out:
# 72

# %%
#soal no. 2 (Hasil operasi disimpan ke dalam variabel)
Total_jumlah_botol = 24 * 3

print(Total_jumlah_botol)
# Out:
# 72

# %%
#soal no. 3 (Operand disimpan kedalam variabel)
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3

print(Banyak_botol_per_kardus * Jumlah_kardus)
# Out:
# 72

# %%
#soal no.4 (operand dan hasil operasi disimpan ke variabel)
Banyak_botol_per_kardus = 24
Jumlah_kardus = 3

# %% [markdown]
# #Operator Aritmatika

# %%
buku_tulis_himam = 55
buku_tulis_vico = 15

# %%
#Penjumlahan
total_buku_tulis = buku_tulis_himam + buku_tulis_vico
print(total_buku_tulis)
# Out:
# 70

# %%
#Pengurangan

selisi_buku_tulis = buku_tulis_himam - buku_tulis_vico
print(selisi_buku_tulis)
# Out:
# 40

# %%
#Perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis = jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus

print(total_buku_tulis)
# Out:
# 30

# %%
#Pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis / jumlah_anak_yatim

print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#Pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#Sisa bagi

sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# 3

# %%
#Perpangkatan

sisi = 5
luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 25

# %% [markdown]
# #Latihan Soal

# %%
#soal no. 1 (Penjumlahan)

apel_dina = 8
apel_ibu_dina = 5
total_apel = apel_dina + apel_ibu_dina

print(total_apel)
# Out:
# 13

# %%
#soal no. 2 (Pengurangan)

mangga_1 = 30
mangga_2 = 12

total_mangga = mangga_1 - mangga_2
print(total_mangga)
# Out:
# 18

# %%
#soal no. 3 (Perkalian)

meja_kelas = 6
meja_1 = 4

total_jumlah_siswa = meja_kelas * meja_1
print(total_jumlah_siswa)
# Out:
# 24

# %%
#soal no. 4 (Pembagian)

jumlah_jeruk = 28
jumlah_keranjang = 7

total_jeruk_setiap_keranjang = jumlah_jeruk / jumlah_keranjang
print(total_jeruk_setiap_keranjang)
# Out:
# 4.0

# %%
#soal no.5 (sisa bagi)
Ayah_membeli_donat = 25
jumlah_anak = 6

total_donat_yang_tersisa = Ayah_membeli_donat // jumlah_anak
print(total_donat_yang_tersisa)
# Out:
# 4

# %%
#soal no.6 (perpangkatan)

sisi = 7

luas_taman = sisi**2
print(luas_taman)
# Out:
# 49

# %% [markdown]
# #Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
nama = "Dzakki"

type(nama)
# Out:
# str

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool
