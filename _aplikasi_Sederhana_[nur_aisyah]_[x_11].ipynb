# %% [markdown]
# <a href="https://colab.research.google.com/github/nuraisyahh/KKA-X-Semester-1/blob/main/_aplikasi_Sederhana_%5Bnur_aisyah%5D_%5Bx_11%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama = Nur aisyah
#
# Kelas= X=11
#
# No.absen=26
#
# Nama kelompok:Panda imoet

# %% [markdown]
# #Aplikasi Sederhana Menghitung Volume Bola

# %%
jari_jari = int(input("Masukkan jari-jari dari bola (cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print(f"volume bola adalah {volume_bola} cm^3. ")
# Out:
# Masukkan jari-jari dari bola (cm): 7
# volume bola adalah 1437.333333333333 cm^3.

# %% [markdown]
# #Aplikasi Sederhana Menghitung Volume Kerucut

# %%
jari_jari=int(input("Masukkan jari_jari dari kerucut(cm): "))
tinggi=int(input("Masukkan tinggi dari kerucut (cm): "))
pi = 22/7
volume_kerucut = 1/3 * pi * jari_jari **2*tinggi
print(f"Volume kerucut adalah {volume_kerucut}cm^2")
# Out:
# Masukkan jari_jari dari kerucut(cm): 4
# Masukkan tinggi dari kerucut (cm): 7
# Volume kerucut adalah 117.33333333333331cm^2
